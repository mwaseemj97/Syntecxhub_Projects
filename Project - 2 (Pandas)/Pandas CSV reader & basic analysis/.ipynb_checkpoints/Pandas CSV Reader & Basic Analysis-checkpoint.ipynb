# %% [markdown]
# # Basic Data Analysis with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/PMLS/Desktop/Project - 2/Pandas CSV reader & basic analysis/dataset_toyota.csv') # loading dataset while using path of the file

# %%
df # looking at the file data
# Out:
#    record_id   date      city          plant vehicle_variant shift  \
# 0       R01A  45658   Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658    Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689   KARACHI  Karachi Plant            Revo     A
# 3       R02B  45689    lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi   Karachi Plant        Fortuner     A
# 5       R03B  45717   LAHORE    Lahore Plant           Yaris     B
# 6       R04A  45748       NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748   Karachi  Karachi Plant            Revo     B
# 8       R05A  45778    Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi   Karachi Plant           Yaris     B
# 10      R06A  45809       NaN  Karachi Plant            Revo     A
# 11      R06B  45809    lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839   KARACHI  Karachi Plant        Fortuner     A
# ...

# %% [markdown]
# # Inspecting Data

# %%
df.head()
# Out:
#   record_id   date      city          plant vehicle_variant shift  \
# 0      R01A  45658   Karachi  Karachi Plant       Corolla X     A
# 1      R01B  45658    Lahore   Lahore Plant           Yaris     B
# 2      R02A  45689   KARACHI  Karachi Plant            Revo     A
# 3      R02B  45689    lahore   Lahore Plant   Corolla Altis     B
# 4      R03A  45717  Karachi   Karachi Plant        Fortuner     A
#
#   units_checked defects_found repair_hours  scrap_weight inspection_team
# 0           200             1            2          10.0          Team A
# 1           150             0            1           5.0          Team B
# 2           300             2            3          15.0          Team A
# 3           NaN             ?      missing          20.0          Team C
# 4           600             3           12         300.0          Team A

# %%
df.tail()
# Out:
#    record_id   date      city          plant vehicle_variant shift  \
# 15      R08B  45870   Karachi  Karachi Plant            Revo     B
# 16      R09A  45901    Lahore   Lahore Plant           Yaris     A
# 17      R09B  45901   KARACHI  Karachi Plant   Corolla Altis     B
# 18      R10A  45931    lahore   Lahore Plant        Fortuner     A
# 19      R10B  45931  Karachi   Karachi Plant            Revo     B
#
#    units_checked defects_found repair_hours  scrap_weight inspection_team
# 15           300             2            3          15.0          Team C
# 16           500             1            2          20.0          Team A
# 17           600             3           12         300.0          Team B
# 18           150             0            1           5.0          Team C
# 19           200             2            3          10.0          Team A

# %%
df.dtypes
# Out:
# record_id           object
# date                 int64
# city                object
# plant               object
# vehicle_variant     object
# shift               object
# units_checked       object
# defects_found       object
# repair_hours        object
# scrap_weight       float64
# inspection_team     object
# dtype: object

# %% [markdown]
# # Computing Summary of Data

# %%
df.describe() # This describes the maximum, minimum, mean, median and standard deviation of the data.
# Out:
#                date  scrap_weight
# count     20.000000     19.000000
# mean   45794.000000     57.368421
# std       89.481548    108.055650
# min    45658.000000      5.000000
# 25%    45717.000000     10.000000
# 50%    45793.500000     15.000000
# 75%    45870.000000     20.000000
# max    45931.000000    300.000000

# %% [markdown]
# # Filtering Rows, Selecting Columns and Slicing Subsets

# %%
df['units_checked'] = df['units_checked'].fillna(any)

# %%
df['units_checked'] = pd.to_numeric(df['units_checked'], errors='coerce')

# %%
df[df['units_checked'] > 150]
# Out:
#    record_id   date      city          plant vehicle_variant shift  \
# 0       R01A  45658   Karachi  Karachi Plant       Corolla X     A
# 2       R02A  45689   KARACHI  Karachi Plant            Revo     A
# 4       R03A  45717  Karachi   Karachi Plant        Fortuner     A
# 7       R04B  45748   Karachi  Karachi Plant            Revo     B
# 9       R05B  45778  Karachi   Karachi Plant           Yaris     B
# 11      R06B  45809    lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839   KARACHI  Karachi Plant        Fortuner     A
# 14      R08A  45870   LAHORE    Lahore Plant       Corolla X     A
# 15      R08B  45870   Karachi  Karachi Plant            Revo     B
# 16      R09A  45901    Lahore   Lahore Plant           Yaris     A
# 17      R09B  45901   KARACHI  Karachi Plant   Corolla Altis     B
# 19      R10B  45931  Karachi   Karachi Plant            Revo     B
#
#     units_checked defects_found repair_hours  scrap_weight inspection_team
# ...

# %%
df[['record_id','shift'][0:5]]
# Out:
#    record_id shift
# 0       R01A     A
# 1       R01B     B
# 2       R02A     A
# 3       R02B     B
# 4       R03A     A
# 5       R03B     B
# 6       R04A     A
# 7       R04B     B
# 8       R05A     A
# 9       R05B     B
# 10      R06A     A
# 11      R06B     B
# 12      R07A     A
# 13      R07B     B
# 14      R08A     A
# 15      R08B     B
# 16      R09A     A
# 17      R09B     B
# 18      R10A     A
# 19      R10B     B

# %%
df[:4]
# Out:
#   record_id   date     city          plant vehicle_variant shift  \
# 0      R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1      R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2      R02A  45689  KARACHI  Karachi Plant            Revo     A
# 3      R02B  45689   lahore   Lahore Plant   Corolla Altis     B
#
#    units_checked defects_found repair_hours  scrap_weight inspection_team
# 0          200.0             1            2          10.0          Team A
# 1          150.0             0            1           5.0          Team B
# 2          300.0             2            3          15.0          Team A
# 3            NaN             ?      missing          20.0          Team C

# %%
df['city'] = df['city'].str.strip().str.lower()

# %%
df.head()
# Out:
#   record_id   date     city          plant vehicle_variant shift  \
# 0      R01A  45658  karachi  Karachi Plant       Corolla X     A
# 1      R01B  45658   lahore   Lahore Plant           Yaris     B
# 2      R02A  45689  karachi  Karachi Plant            Revo     A
# 3      R02B  45689   lahore   Lahore Plant   Corolla Altis     B
# 4      R03A  45717  karachi  Karachi Plant        Fortuner     A
#
#    units_checked defects_found repair_hours  scrap_weight inspection_team
# 0          200.0             1            2          10.0          Team A
# 1          150.0             0            1           5.0          Team B
# 2          300.0             2            3          15.0          Team A
# 3            NaN             ?      missing          20.0          Team C
# 4          600.0             3           12         300.0          Team A

# %%
df['city'] = df['city'].str.strip().str.title()

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['repair_hours'] = pd.to_numeric(df['repair_hours'], errors='coerce')

# %%
df['repair_hours'] = df['repair_hours'].fillna(2)

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['repair_hours'] = df['repair_hours'].replace(-1.0, 2)

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['scrap_weight'] = pd.to_numeric(df['scrap_weight'], errors='coerce')

# %%
import numpy as np

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['scrap_weight'].fillna(0, inplace=True)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_39844\2943028706.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['scrap_weight'].fillna(0, inplace=True)

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['units_checked'].fillna(0, inplace=True)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_39844\748647404.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['units_checked'].fillna(0, inplace=True)

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %%
df['defects_found'] = pd.to_numeric(df['defects_found'], errors='coerce')

# %%
df['defects_found'] = df['defects_found'].replace(-5.0, 5)

# %%
df
# Out:
#    record_id   date     city          plant vehicle_variant shift  \
# 0       R01A  45658  Karachi  Karachi Plant       Corolla X     A
# 1       R01B  45658   Lahore   Lahore Plant           Yaris     B
# 2       R02A  45689  Karachi  Karachi Plant            Revo     A
# 3       R02B  45689   Lahore   Lahore Plant   Corolla Altis     B
# 4       R03A  45717  Karachi  Karachi Plant        Fortuner     A
# 5       R03B  45717   Lahore   Lahore Plant           Yaris     B
# 6       R04A  45748      NaN  Karachi Plant       Corolla X     A
# 7       R04B  45748  Karachi  Karachi Plant            Revo     B
# 8       R05A  45778   Lahore   Lahore Plant   Corolla Altis     A
# 9       R05B  45778  Karachi  Karachi Plant           Yaris     B
# 10      R06A  45809      NaN  Karachi Plant            Revo     A
# 11      R06B  45809   Lahore   Lahore Plant       Corolla X     B
# 12      R07A  45839  Karachi  Karachi Plant        Fortuner     A
# ...

# %% [markdown]
# # Saved Cleaned Data in CSV File

# %%
df.to_csv('cleaned_dataset_toyota.csv', index=False)
